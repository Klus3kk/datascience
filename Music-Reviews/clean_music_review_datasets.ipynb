# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_colwidth", None)

# %%
google_play_path = "google_play_music_reviews.csv"
app_store_path = "app_store_music_reviews.csv"

df_gp = pd.read_csv(google_play_path)
df_as = pd.read_csv(app_store_path)

print("Google Play:", df_gp.shape)
print("App Store:", df_as.shape)
# Out:
# Google Play: (76535, 7)
# App Store: (5640, 7)

# %%
df_gp.head()
# Out:
#                  app                    review  rating  thumbs_up  \
# 0  com.spotify.music                     great       5          0
# 1  com.spotify.music  5 star if u have premium       5          0
# 2  com.spotify.music              too many ads       1          0
# 3  com.spotify.music                      adds       1          0
# 4  com.spotify.music          awesome 👍 thanks       5          0
#
#        version                 date  device
# 0   9.0.42.529  2025-05-22 11:58:57     NaN
# 1  8.6.82.1113  2025-05-22 11:58:46     NaN
# 2   8.9.96.476  2025-05-22 11:57:00     NaN
# 3          NaN  2025-05-22 11:52:40     NaN
# 4   9.0.44.478  2025-05-22 11:50:55     NaN

# %%
df_as.head()
# Out:
#            app country                                 title  \
# 0  Apple Music      US                                4 star
# 1  Apple Music      US                                 Songs
# 2  Apple Music      US                             Encantado
# 3  Apple Music      US                               Love it
# 4  Apple Music      US  Very convenient and I would consider
#
#                                                                                                                                                                                                                                                                review  \
# 0                                                                                                                                                                         I tunes don’t have all the songs like to listen but it has majority. I’m stratified with it
# 1                                                                                                                                                                                                                     Good songs especially taking home country roads
# 2                                                                                                                                                                                                                                         Me encanta esta aplicación.
# 3                                                                                                                                                                             Love a lot of stuff on here love that it blanks out bad words if you have restrictions!
# 4  I love Apple Music because it doesn’t have any adds unlike Spotify or Pandora. I created my account for free and I love listening to my music. It has all new songs from your favorite artists and updates and even podcasts!!! I would HIGHLY RECOMMEND!!!!!! 👍👍👍
#
#    rating                       date                  scraped_at
# 0       4  2025-05-21T18:50:04-07:00  2025-05-23T10:08:45.209909
# 1       4  2025-05-21T18:20:31-07:00  2025-05-23T10:08:45.209934
# 2       5  2025-05-21T17:44:36-07:00  2025-05-23T10:08:45.209940
# 3       5  2025-05-21T17:40:19-07:00  2025-05-23T10:08:45.209945
# 4       5  2025-05-21T17:19:50-07:00  2025-05-23T10:08:45.209949

# %%
app_map = {
    "com.spotify.music": "Spotify",
    "com.apple.android.music": "Apple Music",
    "com.soundcloud.android": "SoundCloud",
    "com.aspiro.tidal": "TIDAL",
    "deezer.android.app": "Deezer",
    "com.shazam.android": "Shazam",
    "com.google.android.music": "Google Play Music"
}
df_gp["app"] = df_gp["app"].map(app_map).fillna(df_gp["app"])

df_gp.drop(columns=["thumbs_up", "device", "scraped_at"], errors="ignore", inplace=True)

df_gp["date"] = pd.to_datetime(df_gp["date"], errors="coerce")

df_gp.dropna(subset=["review", "rating", "date"], inplace=True)
df_gp["rating"] = df_gp["rating"].astype(int)

df_gp = df_gp.sort_values("date", ascending=False)
df_gp.head()
# Out:
#        app                    review  rating      version                date
# 0  Spotify                     great       5   9.0.42.529 2025-05-22 11:58:57
# 1  Spotify  5 star if u have premium       5  8.6.82.1113 2025-05-22 11:58:46
# 2  Spotify              too many ads       1   8.9.96.476 2025-05-22 11:57:00
# 3  Spotify                      adds       1          NaN 2025-05-22 11:52:40
# 4  Spotify          awesome 👍 thanks       5   9.0.44.478 2025-05-22 11:50:55

# %%
df_as["date"] = pd.to_datetime(df_as["date"], errors="coerce")
df_as.dropna(subset=["review", "rating", "date"], inplace=True)
df_as["rating"] = df_as["rating"].astype(int)
df_as.drop(columns=["scraped_at"], errors="ignore", inplace=True)
df_as["date"] = pd.to_datetime(df_as["date"], errors="coerce")
df_as = df_as.sort_values("date", ascending=False)
df_as.head()
# Out:
#               app country  \
# 1850      Spotify      MX
# 2750   SoundCloud      US
# 1851      Spotify      MX
# 3750       Deezer      US
# 0     Apple Music      US
#
#                                                            title  \
# 1850  Muy buena aplicación de música. Casi sin anuncios solo dos
# 2750                              I have loved you from day 1 bi
# 1851                                                     Los amo
# 3750               Must have a premium account to download music
# 0                                                         4 star
#
#                                                                                                                                                                                                                                                                                                                                    review  \
# 1850                                                                                                                                                                                                                                                                                                                                   La
# 2750                                                                                                                                                                                                                                                                                   Nah fr tho, omm nothing but love for SoundCloud ❤️
# 1851                                                                                                                                                                                                                                                                                                                              Los amo
# 3750  I got this music app so I could download songs and listen to them on airplane mode. It requires you to make an account and pick your favorite artists only to say you have to pay in order to download songs. Waste of my time.\nIf you are not using it on an airplane, then it seems like a decent app, but disappointing for me.
# 0                                                                                                                                                                                                                                             I tunes don’t have all the songs like to listen but it has majority. I’m stratified with it
#
#       rating                      date
# 1850       5 2025-05-21 18:57:56-07:00
# 2750       5 2025-05-21 18:56:41-07:00
# 1851       5 2025-05-21 18:56:12-07:00
# 3750       1 2025-05-21 18:50:34-07:00
# 0          4 2025-05-21 18:50:04-07:00

# %%
df_gp.to_csv("clean_google_play_music_reviews.csv", index=False)
df_as.to_csv("clean_app_store_music_reviews.csv", index=False)
print("Cleaned datasets saved.")
# Out:
# Cleaned datasets saved.

# %%
df_gp["source"] = "Google Play"
df_as["source"] = "App Store"

df_merge = pd.concat([df_gp, df_as], ignore_index=True)
df_merge.sample(5)
# Out:
#                app  \
# 23195   SoundCloud
# 57798  Apple Music
# 13358      Spotify
# 78262       Shazam
# 50639  Apple Music
#
#                                                                                                                                                                                                                                          review  \
# 23195                                                                                                                                                                                                                        Good App I like it
# 57798           Subscription issue, Worst subscription I had used. When I unsubscribes apple music still it charged from my account even though it was stopped. Even put a complaint about it but no response. Worst customer service ever!!!!!
# 13358  I like it, but I always have issues when going from listening to my Playlist in my office, then go to my car, it starts over from when I stopped listening in my car before I got to the office. I deal with it but it's quite annoying.
# 78262                                                                                                                                                                shazam werkt niet meer met voiceover. ging altijd goed, maar nu niet meer.
# 50639                                                                           songs still freeze when busy on another app. the search bar in the library is useless as it will find the song, but will play the song that was recently added.
#
#        rating             version                       date       source  \
# 23195       5  2025.02.25-release        2025-03-04 01:09:09  Google Play
# 57798       1                 NaN        2023-04-21 12:53:31  Google Play
# 13358       4          9.0.42.529        2025-05-09 18:35:38  Google Play
# 78262       1                 NaN  2025-05-13 03:27:30-07:00    App Store
# 50639       1               4.5.0        2023-11-14 13:52:51  Google Play
#
#       country                   title
# 23195     NaN                     NaN
# 57798     NaN                     NaN
# 13358     NaN                     NaN
# 78262      NL  probleem met voiceover
# 50639     NaN                     NaN
