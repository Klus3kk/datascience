# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib as mpl
import sys
sys.version
pd.__version__
mpl.__version__
# Out:
# '3.8.4'

# %%
p = np.linspace(0,20,100)
plt.plot(p, np.sin(p))
plt.show()
